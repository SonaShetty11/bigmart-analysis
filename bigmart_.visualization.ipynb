# %%
# !pip install sqlalchemy pymysql mysql-connector-python

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine=create_engine("mysql+pymysql://root:m%40ethu122020@localhost:3306/Bigmart_db")
print("Connection engine created successfully!")
# Out:
# Connection engine created successfully!

# %%
df=pd.read_sql("SELECT DATABASE();",engine)
print(df)
# Out:
#    DATABASE()
# 0  bigmart_db

# %%
df=pd.read_sql("SHOW TABLES;",engine)
print(df)
# Out:
#   Tables_in_bigmart_db
# 0        bigmart_sales

# %%
df_count =pd.read_sql("SELECT COUNT(*) AS total_rows FROM bigmart_sales;",engine)
print(df_count)
# Out:
#    total_rows
# 0        7060

# %% [markdown]
# # **Big Mart Sales Data**

# %%
df_bigmart_sales=pd.read_sql("SELECT * FROM bigmart_sales;",engine)
display(df_bigmart_sales)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat             0.02
# 1              DRC01        5.920          Regular             0.02
# 2              FDN15       17.500          Low Fat             0.02
# 3              FDX07       19.200          Regular             0.00
# 4              NCD19        8.930          Low Fat             0.00
# ...              ...          ...              ...              ...
# 7055           FDF22        6.865          Low Fat             0.06
# 7056           FDS36        8.380          Regular             0.05
# 7057           NCJ29       10.600          Low Fat             0.04
# 7058           FDN46        7.210          Regular             0.15
# 7059           DRG01       14.800          Low Fat             0.04
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy    249.81            OUT049
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Top 10 Rows**

# %%
df=df_bigmart_sales
df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat             0.02
# 1           DRC01        5.920          Regular             0.02
# 2           FDN15       17.500          Low Fat             0.02
# 3           FDX07       19.200          Regular             0.00
# 4           NCD19        8.930          Low Fat             0.00
# 5           FDP36       10.395          Regular             0.00
# 6           FDO10       13.650          Regular             0.01
# 7           FDH17       16.200          Regular             0.02
# 8           FDU28       19.200          Regular             0.09
# 9           FDY07       11.800          Low Fat             0.00
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# ...

# %%
df=df_bigmart_sales
df.head(20)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat             0.02
# 1            DRC01        5.920          Regular             0.02
# 2            FDN15       17.500          Low Fat             0.02
# 3            FDX07       19.200          Regular             0.00
# 4            NCD19        8.930          Low Fat             0.00
# 5            FDP36       10.395          Regular             0.00
# 6            FDO10       13.650          Regular             0.01
# 7            FDH17       16.200          Regular             0.02
# 8            FDU28       19.200          Regular             0.09
# 9            FDY07       11.800          Low Fat             0.00
# 10           FDA03       18.500          Regular             0.05
# 11           FDX32       15.100          Regular             0.10
# 12           FDS46       17.600          Regular             0.05
# ...

# %% [markdown]
# # **Bottom 10 Rows**

# %%
df=df_bigmart_sales
df.tail(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7050           FDH31       12.000          Regular             0.02
# 7051           FDA01       15.000          Regular             0.05
# 7052           FDH24       20.700          Low Fat             0.02
# 7053           NCJ19       18.600          Low Fat             0.12
# 7054           FDF53       20.750          Regular             0.08
# 7055           FDF22        6.865          Low Fat             0.06
# 7056           FDS36        8.380          Regular             0.05
# 7057           NCJ29       10.600          Low Fat             0.04
# 7058           FDN46        7.210          Regular             0.15
# 7059           DRG01       14.800          Low Fat             0.04
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 7050                Meat     99.90            OUT035
# 7051              Canned     57.59            OUT045
# 7052        Baking Goods    157.53            OUT018
# ...

# %% [markdown]
# # **Size of the Data**

# %%
df=df_bigmart_sales
print("Size of Data:", df.shape)
# Out:
# Size of Data: (7060, 12)

# %% [markdown]
# # **Field information**

# %%
df=df_bigmart_sales
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
print(df['Item_Fat_Content'].unique())
# Out:
# ['Low Fat' 'Regular']

# %% [markdown]
# # **KPI's Requirements**

# %%
#Total Sales
total_sales =df['Item_Outlet_Sales'].sum()

#Average Sales
avg_sales =df['Item_Outlet_Sales'].mean()

#Number of items sold
Number_of_items_sold =df['Item_Outlet_Sales'].count()

#Display

print(f"Total Sales: ${total_sales:,.1f}")
print(f"Average Sales: ${avg_sales:,.1f}")
print(f"Number of Items Sold: ${Number_of_items_sold:,.1f}")
# Out:
# Total Sales: $14,957,505.5
# Average Sales: $2,118.6
# Number of Items Sold: $7,060.0

# %% [markdown]
# # **Chart's Requirements**

# %% [markdown]
# ### **Total Sales by Fat Content**

# %%
sales_by_fat =df.groupby('Item_Fat_Content')['Item_Outlet_Sales'].sum()
plt.pie(sales_by_fat, labels= sales_by_fat.index, 
                        autopct = '%.1f%%',
                        startangle =90)

          
plt.title('Sales by Fat Content')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## **Total Sales by Item Type**

# %%
sales_by_item =df.groupby('Item_Type')['Item_Outlet_Sales'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
plt.bar(sales_by_item.index, sales_by_item.values)

plt.xticks(rotation=-90)
plt.xlabel('Item Type')
plt.ylabel('Total Sales')
plt.title('Total Sales by Item Type')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Fat Content by outlet for Total Sales**

# %%
grouped =df.groupby(['Outlet_Location_Type','Item_Fat_Content'])['Item_Outlet_Sales'].sum().unstack()
grouped =grouped[['Regular','Low Fat']]

ax =grouped.plot(kind='bar', figsize=(8,5), title='Outlet Tier by Item Fat Content')
plt.xlabel('Outlet Location Tier')
plt.ylabel('Total Sales')
plt.legend(title='Item Fat Content')                
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Total Sales by outlet Establishment**

# %%
sales_by_year =df.groupby('Outlet_Establishment_Year')['Item_Outlet_Sales'].sum().sort_index()

plt.figure(figsize=(9,5))
plt.plot(sales_by_year.index, sales_by_year.values, marker='o', linestyle='-')
         
plt.xlabel('Outlet_Establishment_Year')
plt.ylabel('Total Sales')
plt.title('Sales by Outlet_Establishment')              
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Sales by outlet size**

# %%
sales_by_size =df.groupby('Outlet_Size')['Item_Outlet_Sales'].sum()
plt.figure(figsize=(4,4))
plt.pie(sales_by_size, labels= sales_by_size.index, 
                        autopct = '%1.1f%%',
                        startangle =90)

          
plt.title('Sales by Outlet Size')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Sales by outlet location**

# %%
sales_by_location =df.groupby('Outlet_Location_Type')['Item_Outlet_Sales'].sum().reset_index()
sales_by_location = sales_by_location.sort_values('Item_Outlet_Sales', ascending=False)

plt.figure(figsize=(8,5)) #smaller height, enough width
ax =sns.barplot(x='Item_Outlet_Sales',y= 'Outlet_Location_Type',data=sales_by_location)
        
plt.title('Sales by Outlet Location Type')
plt.xlabel('Total Sales')
plt.ylabel('Outlet_Location_Type')

plt.tight_layout() # Ensures layout fits without scroll
plt.show()
